# %% [markdown]
# Это проект по подсчёту статистики по оценкам на моём курсе по питону в вышке.
# Кто-то написал в чатике, что питон сложнее экономики и я решил это опровергнуть. И таки опроверг!

# %%
from collections import Counter
import csv
with open('input.txt',encoding='UTF-8') as f:
    full = f.readlines()
full=[item.split(sep='\t') for item in full]

grades=[jtem[-2] for jtem in full]
cnt_grades=Counter(grades)
list_grades=[(int(item), cnt_grades[item]) for item in cnt_grades]
list_grades.sort()
print()
with open('output.tsv','w',encoding='utf-8') as f:
    for ktem in list_grades:
        f.write(str(ktem[0])+'\t'+str(ktem[1])+'\n')
group={}
for item in full:
    group.setdefault(item[3], [])
    group[item[3]].append(int(item[-2]))
print(group)
group_avg=[(item, sum(group[item])/len(group[item])) for item in group]
print(group_avg)
with open('output.tsv','a',encoding='utf-8') as f:
    for ktem in group_avg:
        f.write(str(ktem[0])+'\t'+str(ktem[1])+'\n')
# Out:
# {'БЭК196': [4], 'БЭК197': [5], 'БЭК198': [6], 'БЭК199': [7], 'БЭК2011': [10], 'БЭК2012': [7, 5], 'БЭК209': [5], 'БЭК211': [7, 7, 9, 9, 8, 9, 4, 9, 4, 8, 7, 4, 6, 8, 3, 6, 9, 4, 5, 2, 7, 7, 9, 5, 8, 8], 'БЭК2111': [6, 1, 6, 6, 5, 5, 7, 8, 7, 5, 2, 10, 6, 7, 8, 4, 8, 5, 7, 8, 0, 7, 6, 8, 8, 8, 7, 8], 'БЭК2112': [9, 5, 0, 8, 4, 4, 4, 6, 2, 8, 3, 5, 3, 7, 4, 0, 4, 10, 6, 7, 4, 4, 7, 6, 4, 7, 8, 8], 'БЭК2113': [7, 0, 7, 0, 0, 3, 0], 'БЭК212': [8, 7, 9, 4, 10, 10, 6, 6, 10, 6, 10, 10, 10, 6, 9, 6, 6, 5, 2, 5, 9, 10, 8, 7], 'БЭК213': [9, 7, 6, 3, 5, 8, 8, 8, 10, 5, 3, 8, 3, 9, 7, 5, 5, 4, 4, 4, 8, 7, 9, 10], 'БЭК214': [7, 8, 3, 5, 9, 2, 2, 4, 9, 0, 5, 6, 8, 9, 6, 10, 5, 10, 5, 7, 8, 4, 6], 'БЭК215': [10, 7, 6, 0, 10, 3, 9, 8, 9, 8, 0, 6, 9, 9, 9, 8, 1, 5, 3, 7, 5, 9, 8, 10, 6, 7, 5, 8, 7, 9, 6, 6], 'БЭК216': [6, 9, 7, 10, 7, 6, 5, 7, 9, 6, 9, 6, 6, 7, 5, 6, 8, 10, 8, 7, 9, 10, 3, 8, 9, 6, 7, 3, 9, 7, 5, 10, 8, 5], 'БЭК217': [7, 7, 8, 2, 8, 5, 4, 3, 4, 7, 0, 6, 9, 9, 5, 7, 8, 7, 5, 8, 5, 2, 7, 7, 8, 7, 7, 6, 8], 'БЭК218': [7, 8, 3, 3, 4, 5, 9, 7, 2, 2, 8, 4, 9, 8, 8, 6, 4, 6, 0, 6, 9, 7, 4, 5, 8, 4, 7, 8, 5, 9, 2], 'БЭК2110': [8, 8, 6, 7, 6, 8, 10, 8, 10, 2, 5, 1, 0, 7, 7, 5, 8, 6, 2, 6, 7, 7, 8, 7, 7, 7, 7, 7, 8, 7, 1], 'БЭК219': [6, 5, 6, 1, 7, 7, 8, 7, 5, 0, 8, 6, 8, 5, 7, 7, 2, 6, 4, 10, 4, 6, 8, 10, 8, 6, 9, 8, 7, 7], 'БЭК205': [1]}
# [('БЭК196', 4.0), ('БЭК197', 5.0), ('БЭК198', 6.0), ('БЭК199', 7.0), ('БЭК2011', 10.0), ('БЭК2012', 6.0), ('БЭК209', 5.0), ('БЭК211', 6.615384615384615), ('БЭК2111', 6.178571428571429), ('БЭК2112', 5.25), ('БЭК2113', 2.4285714285714284), ('БЭК212', 7.458333333333333), ('БЭК213', 6.458333333333333), ('БЭК214', 6.0), ('БЭК215', 6.65625), ('БЭК216', 7.147058823529412), ('БЭК217', 6.068965517241379), ('БЭК218', 5.709677419354839), ('БЭК2110', 6.225806451612903), ('БЭК219', 6.266666666666667), ('БЭК205', 1.0)]
